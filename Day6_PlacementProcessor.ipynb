# %% [markdown]
# <a href="https://colab.research.google.com/github/lalithadevi199128/ai-mentor-portfolio/blob/main/Day6_PlacementProcessor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai pydantic

# %%
import os, getpass
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = getpass.getpass('Gemini API key: ')
# Out:
# Gemini API key: ··········

# %%
from pydantic import BaseModel
from typing import List, Optional

class Education(BaseModel):
    degree: str
    institution: str
    year: int

class Resume(BaseModel):
    name: str
    email: str
    phone: Optional[str] = None
    education: List[Education]
    skills: List[str]
    projects: List[str] = []
    experience_years: float

# %%
from google import genai
from pydantic import ValidationError

client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

def extract_resume(raw_text: str, max_retries: int = 1) -> Resume:
    """Extract a Resume JSON from raw text. Retries once on schema fail."""
    for attempt in range(max_retries + 1):
        try:
            resp = client.models.generate_content(
                model='gemini-2.5-flash',
                contents=f'Extract a Resume JSON from this text. Return ONLY JSON, no markdown.\n\n{raw_text}',
                config={
                    'response_mime_type': 'application/json',
                    'response_schema': Resume.model_json_schema(),
                },
            )
            return Resume.model_validate_json(resp.text)
        except ValidationError as e:
            if attempt == max_retries:
                raise
            fix_prompt = f'Fix this JSON to match schema. Errors: {e}. Original: {resp.text}'
            resp = client.models.generate_content(
                model='gemini-2.5-flash', contents=fix_prompt,
                config={'response_mime_type': 'application/json',
                        'response_schema': Resume.model_json_schema()})
            return Resume.model_validate_json(resp.text)

# %%
with open('./sample_data/sample_resumes.txt') as f:
    resumes = [r.strip() for r in f.read().split('---') if r.strip()]
print(f'Loaded {len(resumes)} sample résumés')

results = []
errors = []
for i, r in enumerate(resumes):
    try:
        parsed = extract_resume(r)
        results.append(parsed)
        print(f'  [{i+1}] {parsed.name} — {len(parsed.skills)} skills')
    except Exception as e:
        errors.append((i, e))
        print(f'  [{i+1}] FAILED: {type(e).__name__}: {str(e)[:120]}')

print(f'\n{len(results)}/5 succeeded, {len(errors)} failed')
# Out:
# Loaded 5 sample résumés
#   [1] Ravi Kumar — 6 skills
#   [2] Sneha Reddy — 6 skills
#   [3] Arun Pillai — 8 skills
#   [4] Priya Nair — 5 skills
#   [5] Karthik Sharma — 5 skills
#
# 5/5 succeeded, 0 failed

# %%
# Empty string
try:
    bad = extract_resume('')
    print('Unexpected success:', bad.model_dump_json())
except Exception as e:
    print(f'Empty input: {type(e).__name__}: {str(e)[:200]}')

# Whitespace only
try:
    bad = extract_resume('   \n\n   ')
    print('Unexpected success:', bad.model_dump_json())
except Exception as e:
    print(f'Whitespace input: {type(e).__name__}: {str(e)[:200]}')

# Garbage non-résumé text
try:
    bad = extract_resume('the quick brown fox jumps over the lazy dog')
    print('Garbage input:', bad.model_dump_json())
except Exception as e:
    print(f'Garbage input: {type(e).__name__}: {str(e)[:200]}')
# Out:
# Unexpected success: {"name":"John Doe","email":"john.doe@example.com","phone":"+1-555-123-4567","education":[{"degree":"Master of Science in Computer Science","institution":"University of California, Berkeley","year":2022},{"degree":"Bachelor of Technology in Information Technology","institution":"Indian Institute of Technology, Bombay","year":2020}],"skills":["Python","Java","C++","Data Structures","Algorithms","Machine Learning","Deep Learning","Cloud Computing (AWS)","SQL","NoSQL","Docker","Kubernetes"],"projects":["E-commerce Website with Microservices","AI-powered Recommendation Engine","Distributed File System Implementation"],"experience_years":3.5}
# Unexpected success: {"name":"Unknown","email":"unknown@example.com","phone":null,"education":[],"skills":[],"projects":[],"experience_years":0.0}
# Garbage input: {"name":"N/A","email":"n/a@example.com","phone":null,"education":[],"skills":[],"projects":[],"experience_years":0.0}

# %%
class JD(BaseModel):
    company: str
    role: str
    must_have_skills: List[str]
    nice_to_have_skills: List[str] = []
    min_cgpa: Optional[float] = None
    locations: List[str] = []
    package_lpa: Optional[float] = None

# %%
import requests
from bs4 import BeautifulSoup
import pathlib, json

def fetch_jd(url, max_chars=6000):
    """Fetch JD URL and return clean text. Returns None on block / failure."""
    try:
        r = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}, timeout=10)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, 'html.parser')
        # Remove script and style tags
        for tag in soup(['script', 'style']):
            tag.decompose()
        return soup.get_text(separator='\n', strip=True)[:max_chars]
    except Exception as e:
        print(f'  Scrape failed for {url}: {e}')
        return None

# Test on one URL
test_url = 'https://amazon.jobs/en/jobs/10421853/data-engineer-shiptech-analytics'
text = fetch_jd(test_url)
if text:
    print(f'Got {len(text)} chars')
    print(text[:300])
else:
    print('Scrape blocked. Will use cached set.')
# Out:
# Got 5093 chars
# Data Engineer, ShipTech Analytics - Job ID: 10421853 | Amazon.jobs
# Skip to main content
# ×
# Home
# Teams
# Locations
# Job categories
# My career
# My applications
# My profile
# Account security
# Settings
# Sign out
# Resources
# Accommodations
# Benefits
# Inclusive experiences
# How We Hire
# Leadership principles
# Working at A

# %%
def normalise_jd(text: str) -> JD:
    """Send JD text to Gemini, get structured JD JSON back."""
    resp = client.models.generate_content(
        model='gemini-2.5-flash',
        contents=f'Extract a JD JSON from this text:\n\n{text}',
        config={
            'response_mime_type': 'application/json',
            'response_schema': JD.model_json_schema(),
        },
    )
    return JD.model_validate_json(resp.text)

# Test on one JD text
if text:
    jd = normalise_jd(text)
    print(jd.model_dump_json(indent=2))
# Out:
# {
#   "company": "Amazon",
#   "role": "Data Engineer",
#   "must_have_skills": [
#     "SQL",
#     "Data modeling",
#     "Data warehousing",
#     "ETL pipelines",
#     "Python",
#     "KornShell",
#     "Scala"
#   ],
#   "nice_to_have_skills": [
#     "Hadoop",
#     "Hive",
#     "Spark",
#     "EMR",
#     "AWS Redshift",
#     "AWS S3",
#     "AWS Glue",
#     "AWS Kinesis",
#     "AWS FireHose",
#     "AWS Lambda",
#     "AWS IAM"
#   ],
#   "min_cgpa": null,
#   "locations": [
#     "Hyderabad"
#   ],
#   "package_lpa": null
# }

# %%
import json, pathlib

URLS = [
    # Paste your 5 assigned URLs here
    'https://amazon.jobs/en/jobs/10421853/data-engineer-shiptech-analytics',
    'https://amazon.jobs/en/jobs/10429151/salesforce-developer-dsp-tech-last-mile',
    'https://amazon.jobs/en/jobs/10429156/applied-scientist-rbs-tech',
    'https://amazon.jobs/en/jobs/10386843/software-dev-engineer-ii',
    'https://amazon.jobs/en/jobs/10393375/associate-systems-engineer-windows-region-services',
]

CACHE = pathlib.Path('../data/jds_cached.jsonl')
USE_CACHE = False   # set True if scraping is blocked

jds = []

if USE_CACHE and CACHE.exists():
    print(f'Using cached JDs from {CACHE}')
    for line in CACHE.read_text().splitlines():
        jds.append(JD.model_validate_json(line))
else:
    for url in URLS:
        text = fetch_jd(url)
        if text is None:
            continue
        try:
            jd = normalise_jd(text)
            jds.append(jd)
            print(f'  ✓ {jd.company} — {jd.role}')
        except Exception as e:
            print(f'  ✗ {url}: {e}')

print(f'\nProcessed {len(jds)} JDs')

# Inspect first 3
for jd in jds[:3]:
    print(f'\n{jd.company} - {jd.role}')
    print(f'  Must: {jd.must_have_skills}')
    print(f'  Nice: {jd.nice_to_have_skills}')
    print(f'  CGPA: {jd.min_cgpa}, LPA: {jd.package_lpa}')
# Out:
#   ✓ Amazon — Data Engineer, ShipTech Analytics
#   ✓ Amazon — Salesforce Developer
#   ✓ Amazon — Applied Scientist
#   ✓ Amazon — Software Dev Engineer II
#   ✗ https://amazon.jobs/en/jobs/10393375/associate-systems-engineer-windows-region-services: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
#
# Processed 4 JDs
#
# Amazon - Data Engineer, ShipTech Analytics
#   Must: ['Data engineering', 'SQL', 'Data modeling', 'Data warehousing', 'ETL pipelines', 'Scripting (Python, KornShell, Scala)']
#   Nice: ['Hadoop', 'Hive', 'Spark', 'EMR', 'Redshift', 'S3', 'AWS Glue', 'Kinesis', 'FireHose', 'Lambda', 'IAM roles and permissions']
#   CGPA: None, LPA: None
#
# Amazon - Salesforce Developer
#   Must: ['Salesforce Configuration', 'Salesforce Development (Force.com, VisualForce, APEX, Lightning Web Components)', 'Web Services', 'APIs', 'System Integrations (Salesforce ecosystem, backend services, AWS)', 'Infrastructure Automation', 'Deployment Support', 'Programming (Python, Ruby, Golang, Java, C++, C#, Rust)', 'Linux/Unix', 'Requirements Analysis', 'Solution Design (Salesforce Platform)', 'Salesforce Support']
#   Nice: ['CI/CD pipelines build processes', 'Engineering Leadership', 'Project Management', 'Building products from scratch', 'Building APIs from scratch', 'Strategic Thinking', 'Tactical Thinking', 'Innovation', 'Cross-functional Collaboration', 'Integrating diverse technologies']
#   CGPA: None, LPA: None
#
# Amazon - Applied Scientist
#   Must: ['Machine Learning', 'Natural Language Processing', 'Computer Vision', 'Deep Learning', 'Generative AI', 'Statistical techniques', 'Communication skills']
#   Nice: ['Research publication', 'Collaboration', 'Scientific thinking', 'Inventive ability', 'Thought leadership', 'Algorithm design', 'Data structures', 'Problem solving', 'Complexity analysis']
#   CGPA: None, LPA: None

# %%
OUT = pathlib.Path('data/jds.jsonl')
OUT.parent.mkdir(exist_ok=True)
with open(OUT, 'w') as f:
    for jd in jds:
        f.write(jd.model_dump_json() + '\n')
print(f'Wrote {len(jds)} JDs to {OUT}')

# Verify the file
with open(OUT) as f:
    for line in f:
        d = json.loads(line)
        print(f'  {d["company"]:20} | {d["role"]:30} | {len(d["must_have_skills"])} must-haves')
# Out:
# Wrote 4 JDs to data/jds.jsonl
#   Amazon               | Data Engineer, ShipTech Analytics | 6 must-haves
#   Amazon               | Salesforce Developer           | 12 must-haves
#   Amazon               | Applied Scientist              | 7 must-haves
#   Amazon               | Software Dev Engineer II       | 7 must-haves
