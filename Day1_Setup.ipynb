# %% [markdown]
# <a href="https://colab.research.google.com/github/lalithadevi199128/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=''
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the essential capabilities needed for successful AI development and deployment, from foundational to strategic:
#
# *   **Layer 1: Data & Infrastructure:** The base involves skills in data collection, storage, processing, and managing the underlying computational resources.
# *   **Layer 2: Algorithms & Models:** Focuses on expertise in selecting, training, evaluating, and optimizing various machine learning algorithms and pre-trained models.
# *   **Layer 3: Development & Engineering:** Encompasses software engineering principles to build robust AI applications, integrate models, and manage deployment (MLOps).
# *   **Layer 4 & 5: Domain Expertise, Business Acumen & Ethics:** The top layers require understanding the problem context, identifying business value, and ensuring responsible, ethical, and governable AI solutions.
