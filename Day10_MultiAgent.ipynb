# %% [markdown]
# <a href="https://colab.research.google.com/github/lalithadevi199128/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 132a4fb3-209a-4a76-b95f-57d02c2d87b9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 925ae53b-2475-4b28-8217-cba6ae9b3f4e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement preparation brief for TCS Digital for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes sections on cognitive ability (verbal, numerical, reasoning),    │
# │  advanced aptitude, and advanced coding challenges.                                                             │
# │  *   **Technical Interview:** Focuses on Data Structures & Algorithms (DSA), core programming concepts,         │
# │  project discussions, and knowledge of computer science fundamentals (OS, DBMS, CN).                            │
# │  *   **Managerial Interview:** Assesses problem-solving approach, project management skills, leadership         │
# │  potential, and ability to handle real-world scenarios.                                                         │
# │  *   **HR Interview:** Evaluates communication skills, career aspirations, behavioral traits, and cultural fit  │
# │  within TCS.                                                                                                    │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language such as Java, Python, C++,   │
# │  or JavaScript.                                                                                                 │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental and advanced knowledge of DSA is crucial for           │
# │  problem-solving and coding rounds.                                                                             │
# │  *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JavaScript, React/Angular) and/or back-end    │
# │  frameworks (Spring Boot, Node.js) is often beneficial.                                                         │
# │  *   **Emerging Technologies:** Basic understanding or project experience in areas like Cloud Computing (AWS,   │
# │  Azure, GCP), Artificial Intelligence/Machine Learning, or Data Science is highly valued.                       │
# │  *   **Database & Tools:** Knowledge of SQL/NoSQL databases, version control systems (Git), and software        │
# │  development methodologies (Agile).                                                                             │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics &           │
# │  Communication, Electrical & Electronics, or related branches.                                                  │
# │  *   **Academic Percentage:** Generally requires a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and        │
# │  graduation.                                                                                                    │
# │  *   **Backlogs:** No active backlogs allowed at the time of applying or joining.                               │
# │  *   **Year of Graduation:** Typically targeted towards final-year students.                                    │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Advanced Problem Solving:** Increased emphasis on complex algorithmic problem-solving and competitive    │
# │  programming skills.                                                                                            │
# │  *   **Emerging Tech Readiness:** Higher demand for candidates with practical exposure or certifications in     │
# │  AI/ML, Cloud, IoT, or Blockchain.                                                                              │
# │  *   **Holistic Skillset:** Focus on hiring candidates with not just technical prowess but also strong          │
# │  communication, analytical, and critical thinking abilities.                                                    │
# │  *   **Project-Based Learning:** Preference for students who have undertaken significant projects,              │
# │  internships, or open-source contributions to demonstrate practical application of skills.                      │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on         │
# │  platforms like LeetCode, HackerRank, and GeeksforGeeks.                                                        │
# │  *   **Core Concepts Strong:** Solidify your understanding of Object-Oriented Programming (OOP), Operating      │
# │  Systems (OS), Database Management Systems (DBMS), and Computer Networks (CN).                                  │
# │  *   **Projects & Technologies:** Build diverse projects to showcase your skills; gain foundational knowledge   │
# │  in trending technologies like Cloud (e.g., AWS basics), AI/ML, or web development frameworks.                  │
# │  *   **Communication & Soft Skills:** Practice articulating your thoughts clearly, explaining technical         │
# │  concepts, and discussing project experiences effectively.                                                      │
# │  *   **Mock Interviews:** Participate in mock technical and HR interviews to get familiar with the process,     │
# │  receive feedback, and improve your confidence.                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 71980379-5935-449d-b115-c6289c23f121                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Unlock a world of innovation and accelerated career growth with TCS Digital! This brief outlines the key       │
# │  areas to focus on for securing your dream role. Prepare to showcase your advanced technical skills and         │
# │  problem-solving prowess to join the cutting edge of technology.                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. Hiring Process                                                                                          │
# │                                                                                                                 │
# │  Navigate the TCS Digital selection journey, designed to identify top talent with strong technical foundations  │
# │  and innovative mindsets.                                                                                       │
# │                                                                                                                 │
# │  *   **Online Assessment:** Test your cognitive abilities, advanced aptitude, and critical coding skills        │
# │  across multiple programming challenges.                                                                        │
# │  *   **Technical Interview:** Expect deep dives into Data Structures & Algorithms, core programming concepts,   │
# │  project discussions, and CS fundamentals (OS, DBMS, CN).                                                       │
# │  *   **Managerial Interview:** Demonstrate your problem-solving approach, project management potential,         │
# │  leadership qualities, and ability to handle real-world tech scenarios.                                         │
# │  *   **HR Interview:** Assess your communication skills, career aspirations, behavioral traits, and overall     │
# │  cultural fit within TCS.                                                                                       │
# │                                                                                                                 │
# │  ### 2. Technical Stack Essentials                                                                              │
# │                                                                                                                 │
# │  A strong grasp of these technologies will set you apart in the TCS Digital hiring process.                     │
# │                                                                                                                 │
# │  *   **Programming Languages:** Proficiency in at least one modern language like Java, Python, C++, or          │
# │  JavaScript.                                                                                                    │
# │  *   **Data Structures & Algorithms (DSA):** Comprehensive understanding and practical application are          │
# │  non-negotiable for coding rounds.                                                                              │
# │  *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JS, React/Angular) and/or back-end (Spring    │
# │  Boot, Node.js) frameworks.                                                                                     │
# │  *   **Emerging Technologies:** Basic knowledge or project experience in Cloud Computing (AWS, Azure, GCP),     │
# │  AI/ML, or Data Science is a significant advantage.                                                             │
# │  *   **Databases & Tools:** Command over SQL/NoSQL databases, version control (Git), and Agile development      │
# │  methodologies.                                                                                                 │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the academic and foundational requirements before applying.                                    │
# │                                                                                                                 │
# │  *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics &           │
# │  Communication, Electrical & Electronics, or related branches.                                                  │
# │  *   **Academic Percentage:** A consistent minimum of 60% or 6.0 CGPA across 10th, 12th, and graduation.        │
# │  *   **Backlogs:** No active backlogs are permitted at the time of application or joining.                      │
# │  *   **Year of Graduation:** Primarily targeting final-year B.Tech students.                                    │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  Understand the evolving expectations of TCS Digital to tailor your preparation strategically.                  │
# │                                                                                                                 │
# │  *   **Advanced Problem Solving:** Increased focus on complex algorithmic challenges and competitive            │
# │  programming skills.                                                                                            │
# │  *   **Emerging Tech Readiness:** Higher demand for practical exposure, certifications, or projects in AI/ML,   │
# │  Cloud, IoT, or Blockchain.                                                                                     │
# │  *   **Holistic Skillset:** Beyond technical prowess, strong communication, analytical, and critical thinking   │
# │  abilities are highly valued.                                                                                   │
# │  *   **Project-Based Learning:** Preference for candidates demonstrating practical application of skills        │
# │  through significant projects, internships, or open-source contributions.                                       │
# │                                                                                                                 │
# │  ### 5. Essential Prep Tips                                                                                     │
# │                                                                                                                 │
# │  Follow these actionable steps to maximize your chances of success.                                             │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate extensive time to practice on platforms like LeetCode, HackerRank, and   │
# │  GeeksforGeeks.                                                                                                 │
# │  *   **Core Concepts Strong:** Solidify your understanding of OOP, Operating Systems (OS), Database Management  │
# │  Systems (DBMS), and Computer Networks (CN).                                                                    │
# │  *   **Projects & Technologies:** Build diverse and impactful projects; gain foundational knowledge in          │
# │  trending areas like Cloud (e.g., AWS basics), AI/ML, or web development frameworks.                            │
# │  *   **Communication & Soft Skills:** Practice articulating your thoughts clearly, explaining technical         │
# │  concepts, and discussing project experiences effectively.                                                      │
# │  *   **Mock Interviews:** Participate in mock technical and HR interviews to familiarize yourself with the      │
# │  process, gather feedback, and boost your confidence.                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Start your preparation today, focus on building a strong technical foundation, and don't forget to hone your   │
# │  soft skills. Your dedication and smart work will pave the way for a rewarding career with TCS Digital. Good    │
# │  luck!                                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of innovation and accelerated career growth with TCS Digital! This brief outlines the key areas to focus on for securing your dream role. Prepare to showcase your advanced technical skills and problem-solving prowess to join the cutting edge of technology.
#
# ---
#
# ### 1. Hiring Process
#
# Navigate the TCS Digital selection journey, designed to identify top talent with strong technical foundations and innovative mindsets.
#
# *   **Online Assessment:** Test your cognitive abilities, advanced aptitude, and critical coding skills across multiple programming challenges.
# *   **Technical Interview:** Expect deep dives into Data Structures & Algorithms, core programming concepts, project discussions, and CS fundamentals (OS, DBMS, CN).
# *   **Managerial Interview:** Demonstrate your problem-solving approach, project management potential, leadership qualities, and ability to handle real-world tech scenarios.
# *   **HR Interview:** Assess your communication skills, career aspirations, behavioral traits, and overall cultural fit within TCS.
#
# ### 2. Technical Stack Essentials
#
# A strong grasp of these technologies will set you apart in the TCS Digital hiring process.
#
# *   **Programming Languages:** Proficiency in at least one modern language like Java, Python, C++, or JavaScript.
# *   **Data Structures & Algorithms (DSA):** Comprehensive understanding and practical application are non-negotiable for coding rounds.
# *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JS, React/Angular) and/or back-end (Spring Boot, Node.js) frameworks.
# *   **Emerging Technologies:** Basic knowledge or project experience in Cloud Computing (AWS, Azure, GCP), AI/ML, or Data Science is a significant advantage.
# *   **Databases & Tools:** Command over SQL/NoSQL databases, version control (Git), and Agile development methodologies.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the academic and foundational requirements before applying.
#
# *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, or related branches.
# *   **Academic Percentage:** A consistent minimum of 60% or 6.0 CGPA across 10th, 12th, and graduation.
# *   **Backlogs:** No active backlogs are permitted at the time of application or joining.
# *   **Year of Graduation:** Primarily targeting final-year B.Tech students.
#
# ### 4. Recent Hiring Trends
#
# Understand the evolving expectations of TCS Digital to tailor your preparation strategically.
#
# *   **Advanced Problem Solving:** Increased focus on complex algorithmic challenges and competitive programming skills.
# *   **Emerging Tech Readiness:** Higher demand for practical exposure, certifications, or projects in AI/ML, Cloud, IoT, or Blockchain.
# *   **Holistic Skillset:** Beyond technical prowess, strong communication, analytical, and critical thinking abilities are highly valued.
# *   **Project-Based Learning:** Preference for candidates demonstrating practical application of skills through significant projects, internships, or open-source contributions.
#
# ### 5. Essential Prep Tips
#
# Follow these actionable steps to maximize your chances of success.
#
# *   **Master DSA & Coding:** Dedicate extensive time to practice on platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Core Concepts Strong:** Solidify your understanding of OOP, Operating Systems (OS), Database Management Systems (DBMS), and Computer Networks (CN).
# *   **Projects & Technologies:** Build diverse and impactful projects; gain foundational knowledge in trending areas like Cloud (e.g., AWS basics), AI/ML, or web development frameworks.
# *   **Communication & Soft Skills:** Practice articulating your thoughts clearly, explaining technical concepts, and discussing project experiences effectively.
# *   **Mock Interviews:** Participate in mock technical and HR interviews to familiarize yourself with the process, gather feedback, and boost your confidence.
#
# ---
#
# Start your preparation today, focus on building a strong technical foundation, and don't forget to hone your soft skills. Your dedication and smart work will pave the way for a rewarding career with TCS Digital. Good luck!
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4228

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement preparation brief for TCS Digital for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes sections on cognitive ability (verbal, numerical, reasoning), advanced aptitude, and advanced coding challenges.
# *   **Technical Interview:** Focuses on Data Structures & Algorithms (DSA), core programming concepts, project discussions, and knowledge of computer science fundamentals (OS, DBMS, CN).
# *   **Managerial Interview:** Assesses problem-solving approach, project management skills, leadership potential, and ability to handle real-world scenarios.
# *   **HR Interview:** Evaluates communication skills, career aspirations, behavioral traits, and cultural fit within TCS.
#
# ### Technical Stack
# *   **Programming Languages:** Strong proficiency in at lea
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of innovation and accelerated career growth with TCS Digital! This brief outlines the key areas to focus on for securing your dream role. Prepare to showcase your advanced technical skills and problem-solving prowess to join the cutting edge of technology.
#
# ---
#
# ### 1. Hiring Process
#
# Navigate the TCS Digital selection journey, designed to identify top talent with strong technical foundations and innovative mindsets.
#
# *   **Online Assessment:** Test your cognitive abilities, advanced aptitude, and critical coding skills across multiple programming challenges.
# *   **Technical Interview:** Expect deep dives into Data Structures & Algorithms, core programming concepts, project discussions, and CS fundamentals (OS, DBMS, CN).
# *   **Manageria

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Unlock a world of innovation and accelerated career growth with TCS Digital! This brief outlines the key areas to focus on for securing your dream role. Prepare to showcase your advanced technical skills and problem-solving prowess to join the cutting edge of technology.
#
# ---
#
# ### 1. Hiring Process
#
# Navigate the TCS Digital selection journey, designed to identify top talent with strong technical foundations and innovative mindsets.
#
# *   **Online Assessment:** Test your cognitive abilities, advanced aptitude, and critical coding skills across multiple programming challenges.
# *   **Technical Interview:** Expect deep dives into Data Structures & Algorithms, core programming concepts, project discussions, and CS fundamentals (OS, DBMS, CN).
# *   **Managerial Interview:** Demonstrate your problem-solving approach, project management potential, leadership qualities, and ability to handle real-world tech scenarios.
# *   **HR Interview:** Assess your communication skills, career aspirations, behavioral traits, and overall cultural fit within TCS.
#
# ### 2. Technical Stack Essentials
#
# A strong grasp of these technologies will set you apart in the TCS Digital hiring process.
#
# *   **Programming Languages:** Proficiency in at least one modern language like Java, Python, C++, or JavaScript.
# *   **Data Structures & Algorithms (DSA):** Comprehensive understanding and practical application are non-negotiable for coding rounds.
# *   **Web Technologies:** Familiarity with front-end (HTML, CSS, JS, React/Angular) and/or back-end (Spring Boot, Node.js) frameworks.
# *   **Emerging Technologies:** Basic knowledge or project experience in Cloud Computing (AWS, Azure, GCP), AI/ML, or Data Science is a significant advantage.
# *   **Databases & Tools:** Command over SQL/NoSQL databases, version control (Git), and Agile development methodologies.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the academic and foundational requirements before applying.
#
# *   **Acad
